# %% [markdown]
# # Aniket Patil
# ### GitHub Link :- https://github.com/aniketpatil91/RNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
dataset_train = pd.read_csv('IBM.csv')
training_set = dataset_train.iloc[:, 1:2].values

# %%
plt.plot(training_set)

# %%
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))

# %%
training_set_scaled=sc.fit_transform(training_set)

# %%
X=[]
y=[]
for i in range(60,1509):
    X.append(training_set_scaled[i-60:i,0])
    y.append(training_set_scaled[i,0])
X, y = np.array(X), np.array(y)

# %%
X = np.reshape(X, (X.shape[0], X.shape[1],1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=101)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# C:\Users\aniket\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
regressor= Sequential()

# %%
regressor.add(LSTM(units=50, return_sequences= True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units=50, return_sequences= True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units=50, return_sequences= True))
regressor.add(Dropout(0.2))

# %%
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))

# %%
regressor.add(Dense(units=1))

# %%
regressor.compile(optimizer= 'adam', loss ='mean_squared_error')

# %%
regressor.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1014/1014 [==============================] - 5s 5ms/step - loss: 0.0606
# Epoch 2/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0096
# Epoch 3/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0070
# Epoch 4/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0060
# Epoch 5/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0064
# Epoch 6/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0060
# Epoch 7/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0063
# Epoch 8/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0058
# Epoch 9/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0054
# Epoch 10/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0052
# Epoch 11/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0053
# Epoch 12/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0048
# Epoch 13/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0048
# Epoch 14/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0051
# Epoch 15/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0050
# Epoch 16/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0048
# Epoch 17/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0051
# Epoch 18/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0045
# Epoch 19/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0048
# Epoch 20/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0043
# Epoch 21/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0039
# Epoch 22/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0038
# Epoch 23/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0042
# Epoch 24/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0036
# Epoch 25/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0037
# Epoch 26/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0040
# Epoch 27/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0035
# Epoch 28/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0036
# Epoch 29/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0039
# Epoch 30/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0037
# Epoch 31/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0033
# Epoch 32/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0035
# Epoch 33/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0037
# Epoch 34/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0035
# Epoch 35/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0036
# Epoch 36/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0036
# Epoch 37/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0035
# Epoch 38/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0030
# Epoch 39/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0032
# Epoch 40/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0028
# Epoch 41/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0029
# Epoch 42/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0027
# Epoch 43/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0030
# Epoch 44/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0026
# Epoch 45/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0028
# Epoch 46/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0028
# Epoch 47/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0027
# Epoch 48/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0027
# Epoch 49/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0027
# Epoch 50/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 51/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0029
# Epoch 52/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0027
# Epoch 53/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0026
# Epoch 54/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 55/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 56/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0025
# Epoch 57/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 58/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 59/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 60/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0023
# Epoch 61/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 62/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0023
# Epoch 63/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0022
# Epoch 64/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 65/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 66/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 67/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0023
# Epoch 68/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0022
# Epoch 69/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0020
# Epoch 70/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0019
# Epoch 71/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0019
# Epoch 72/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0022
# Epoch 73/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0021
# Epoch 74/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0020
# Epoch 75/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0024
# Epoch 76/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0019
# Epoch 77/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 78/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 79/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 80/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 81/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0020
# Epoch 82/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 83/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 84/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 85/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0019
# Epoch 86/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 87/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0019
# Epoch 88/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 89/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 90/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 91/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0017
# Epoch 92/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 93/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0018
# Epoch 94/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 95/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 96/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 97/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 98/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0015
# Epoch 99/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 100/100
# 1014/1014 [==============================] - 3s 3ms/step - loss: 0.0016

# %%
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price= sc.inverse_transform(predicted_stock_price)
real_stock_price=sc.inverse_transform([y_test])

# %%
plt.figure(figsize=(20,10))
plt.plot(np.reshape(real_stock_price,(predicted_stock_price.shape[0],1)), color='red', label= 'Real IBM Stock Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted IBM Stock Price')
plt.title('IBM stock price prediction')
plt.xlabel('time')
plt.ylabel('IBM Stock Price')
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score,accuracy_score

# %%
r2_score(np.reshape(real_stock_price,(predicted_stock_price.shape[0],1)),predicted_stock_price)
# Out:
# 0.9813402885013688
